# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
ruta="/content/drive/My Drive/progra/datanueva.csv"

# %%
datos=pd.read_csv(ruta)
datos.head()
# Out:
#                Series_Title  ID  \
# 0  The Shawshank Redemption   1
# 1             The Godfather   2
# 2           The Dark Knight   3
# 3    The Godfather: Part II   4
# 4              12 Angry Men   5
#
#                                          Poster_Link Released_Year  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...          1994
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...          1972
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...          2008
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...          1974
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...          1957
#
#   Certificate  Runtime                 Genre  IMDB_Rating  \
# 0           A  142 min                 Drama          9.3
# 1           A  175 min          Crime, Drama          9.2
# 2          UA  152 min  Action, Crime, Drama          9.0
# 3           A  202 min          Crime, Drama          9.0
# 4           U   96 min          Crime, Drama          9.0
#
# ...

# %%
print(f"datos{datos.shape}")
# Out:
# datos(1000, 17)

# %%
datos.describe()
# Out:
#                 ID  IMDB_Rating  Meta_score   No_of_Votes
# count  1000.000000  1000.000000  843.000000  1.000000e+03
# mean    500.500000     7.949300   77.971530  2.736929e+05
# std     288.819436     0.275491   12.376099  3.273727e+05
# min       1.000000     7.600000   28.000000  2.508800e+04
# 25%     250.750000     7.700000   70.000000  5.552625e+04
# 50%     500.500000     7.900000   79.000000  1.385485e+05
# 75%     750.250000     8.100000   87.000000  3.741612e+05
# max    1000.000000     9.300000  100.000000  2.343110e+06

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   1000 non-null   object
#  1   ID             1000 non-null   int64
#  2   Poster_Link    1000 non-null   object
#  3   Released_Year  1000 non-null   object
#  4   Certificate    899 non-null    object
#  5   Runtime        1000 non-null   object
#  6   Genre          1000 non-null   object
#  7   IMDB_Rating    1000 non-null   float64
#  8   Overview       1000 non-null   object
#  9   Meta_score     843 non-null    float64
#  10  Director       1000 non-null   object
#  11  Star1          1000 non-null   object
#  12  Star2          1000 non-null   object
#  13  Star3          1000 non-null   object
#  14  Star4          1000 non-null   object
#  15  No_of_Votes    1000 non-null   int64
#  16  Gross          831 non-null    object
# ...

# %% [markdown]
# identificacion de columnas nulas

# %%
columnasnulas=datos.isnull().any()
columnasnulas
# Out:
# Series_Title     False
# ID               False
# Poster_Link      False
# Released_Year    False
# Certificate       True
# Runtime          False
# Genre            False
# IMDB_Rating      False
# Overview         False
# Meta_score        True
# Director         False
# Star1            False
# Star2            False
# Star3            False
# Star4            False
# No_of_Votes      False
# Gross             True
# dtype: bool

# %% [markdown]
# identificando filas nulas

# %%
filas_nulas= datos[datos.isnull().any(axis=1)]
print(filas_nulas)
# Out:
#                Series_Title    ID  \
# 18                 Hamilton    19
# 20          Soorarai Pottru    21
# 30                  Seppuku    31
# 32    It's a Wonderful Life    33
# 46           Hotaru no haka    47
# ..                      ...   ...
# 993                  Blowup   994
# 995  Breakfast at Tiffany's   996
# 996                   Giant   997
# 998                Lifeboat   999
# 999            The 39 Steps  1000
#
#                                            Poster_Link Released_Year  \
# 18   https://m.media-amazon.com/images/M/MV5BNjViNW...          2020
# 20   https://m.media-amazon.com/images/M/MV5BOTc2ZT...          2020
# 30   https://m.media-amazon.com/images/M/MV5BYjBmYT...          1962
# 32   https://m.media-amazon.com/images/M/MV5BZjc4ND...          1946
# 46   https://m.media-amazon.com/images/M/MV5BZmY2Nj...          1988
# ..                                                 ...           ...
# ...

# %%
####eliminando filas nulas ####

data_sin_nulos= datos.dropna()
data_sin_nulos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 714 entries, 0 to 997
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   714 non-null    object
#  1   ID             714 non-null    int64
#  2   Poster_Link    714 non-null    object
#  3   Released_Year  714 non-null    object
#  4   Certificate    714 non-null    object
#  5   Runtime        714 non-null    object
#  6   Genre          714 non-null    object
#  7   IMDB_Rating    714 non-null    float64
#  8   Overview       714 non-null    object
#  9   Meta_score     714 non-null    float64
#  10  Director       714 non-null    object
#  11  Star1          714 non-null    object
#  12  Star2          714 non-null    object
#  13  Star3          714 non-null    object
#  14  Star4          714 non-null    object
#  15  No_of_Votes    714 non-null    int64
#  16  Gross          714 non-null    object
# ...

# %% [markdown]
# eliminando filas

# %%
nulos_Meta_score=datos[datos["Meta_score"].isnull()]
print(nulos_Meta_score)
# Out:
#                       Series_Title   ID  \
# 20                 Soorarai Pottru   21
# 54       Ayla: The Daughter of War   55
# 55                    Vikram Vedha   56
# 57                          Dangal   58
# 65                Taare Zameen Par   66
# ..                             ...  ...
# 872  The Day the Earth Stood Still  873
# 874                          Gilda  875
# 899                      El cuerpo  900
# 909                      Celda 211  910
# 913                      Die Welle  914
#
#                                            Poster_Link Released_Year  \
# 20   https://m.media-amazon.com/images/M/MV5BOTc2ZT...          2020
# 54   https://m.media-amazon.com/images/M/MV5BNWJhMD...          2017
# 55   https://m.media-amazon.com/images/M/MV5BY2FiMT...          2017
# 57   https://m.media-amazon.com/images/M/MV5BMTQ4Mz...          2016
# 65   https://m.media-amazon.com/images/M/MV5BMDhjZW...          2007
# ...
