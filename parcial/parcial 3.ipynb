# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount("/content/drive")
ruta="/content/drive/My Drive/progra/songs_normalize.csv"
# Out:
# Mounted at /content/drive

# %% [markdown]
# letra A mostrar la informacion general del dataset y la informacion estaddistica resumida

# %%
datos=pd.read_csv(ruta)
datos.head()
datos.describe()
# Out:
#          duration_ms        year   popularity  danceability       energy  \
# count    2000.000000  2000.00000  2000.000000   2000.000000  2000.000000
# mean   228748.124500  2009.49400    59.872500      0.667438     0.720366
# std     39136.569008     5.85996    21.335577      0.140416     0.152745
# min    113000.000000  1998.00000     0.000000      0.129000     0.054900
# 25%    203580.000000  2004.00000    56.000000      0.581000     0.622000
# 50%    223279.500000  2010.00000    65.500000      0.676000     0.736000
# 75%    248133.000000  2015.00000    73.000000      0.764000     0.839000
# max    484146.000000  2020.00000    89.000000      0.975000     0.999000
#
#                key     loudness         mode  speechiness  acousticness  \
# count  2000.000000  2000.000000  2000.000000  2000.000000   2000.000000
# mean      5.378000    -5.512434     0.553500     0.103568      0.128955
# std       3.615059     1.933482     0.497254     0.096159      0.173346
# ...

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artist            2000 non-null   object
#  1   song              1999 non-null   object
#  2   duration_ms       2000 non-null   int64
#  3   explicit          2000 non-null   bool
#  4   year              2000 non-null   int64
#  5   popularity        2000 non-null   int64
#  6   danceability      2000 non-null   float64
#  7   energy            2000 non-null   float64
#  8   key               2000 non-null   int64
#  9   loudness          2000 non-null   float64
#  10  mode              2000 non-null   int64
#  11  speechiness       2000 non-null   float64
#  12  acousticness      2000 non-null   float64
#  13  instrumentalness  2000 non-null   float64
#  14  liveness          2000 non-null   float64
#  15  valence           2000 non-null   float64
# ...

# %%
####letra B contar todos los valores nulos existentes de dataset y imprimirlos .luego eliminar los valores nulos encontrados####

# %%
valores_nulos=datos.isnull().any()
valores_nulos
# Out:
# artist              False
# song                 True
# duration_ms         False
# explicit            False
# year                False
# popularity          False
# danceability        False
# energy              False
# key                 False
# loudness            False
# mode                False
# speechiness         False
# acousticness        False
# instrumentalness    False
# liveness            False
# valence             False
# tempo               False
# genre               False
# dtype: bool

# %%
filas_nulas = datos[datos.isnull().any(axis=1)]
filas_nulas
# Out:
#        artist song duration_ms  explicit  year popularity danceability energy  \
# 21  Tom Jones  NaN      211893     False  1999         65        0.801  0.876
#
#    key loudness mode speechiness acousticness instrumentalness liveness  \
# 21   8    -3.94    0      0.0446        0.144         0.000014    0.104
#
#    valence    tempo                                genre
# 21   0.932  122.979  rock, Folk/Acoustic, easy listening

# %%
data_sin_nulos=datos.dropna()
data_sin_nulos
# Out:
#               artist                                    song duration_ms  \
# 0     Britney Spears                  Oops!...I Did It Again      211160
# 1          blink-182                    All The Small Things      167066
# 2         Faith Hill                                 Breathe      250546
# 3           Bon Jovi                            It's My Life      224493
# 4             *NSYNC                             Bye Bye Bye      200560
# ...              ...                                     ...         ...
# 1995  Jonas Brothers                                  Sucker      181026
# 1996    Taylor Swift                            Cruel Summer      178426
# 1997    Blanco Brown                              The Git Up      200593
# 1998       Sam Smith  Dancing With A Stranger (with Normani)      171029
# 1999     Post Malone                                 Circles      215280
#
#       explicit  year popularity danceability energy key loudness mode  \
# ...

# %%
data_sin_nulos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1999 entries, 0 to 1999
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artist            1999 non-null   object
#  1   song              1999 non-null   object
#  2   duration_ms       1999 non-null   object
#  3   explicit          1999 non-null   bool
#  4   year              1999 non-null   object
#  5   popularity        1999 non-null   object
#  6   danceability      1999 non-null   object
#  7   energy            1999 non-null   object
#  8   key               1999 non-null   object
#  9   loudness          1999 non-null   object
#  10  mode              1999 non-null   object
#  11  speechiness       1999 non-null   object
#  12  acousticness      1999 non-null   object
#  13  instrumentalness  1999 non-null   object
#  14  liveness          1999 non-null   object
#  15  valence           1999 non-null   object
# ...

# %% [markdown]
# LETRA C  FILTRAR CANCIONES CON CONTENIDO EXPLICITO("EXPLICIT").MOSTRAR LAS PRIMERAS 10 CANCIONES CON CONTENIDO EXPLICITO EN FORMATO TABLA

# %%
exp_song=datos[datos["explicit"]=True]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-b571f1e032e2> in <cell line: 1>()
# ----> 1 exp_song=datos[datos["explicit"].apply()]
#       2 exp_song
#
# TypeError: Series.apply() missing 1 required positional argument: 'func'

# %% [markdown]
# LETRA D OBTENER EL PROMEDIO DE LA DURACION DE TODAS LAS CANCIONES

# %%
data_sin_nulos.duration_ms.mean()
# Out:
# 163543.60580290144

# %% [markdown]
# GRAFICO

# %%
plt.figure()
plt.plot()
plt.title("Cantidad de canciones explicitas")
plt.xlabel("canciones explicitas")
plt.ylabel("artistas")
plt.show()
